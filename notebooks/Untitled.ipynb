# %%
from scipy.io import wavfile
import matplotlib.pyplot as plt
import os

# %%
os.getcwd()
# Out:
# '/Users/jameshill/PycharmProjects/bioacoustic-classifier/notebooks'

# %%
os.chdir('/Users/jameshill/PycharmProjects/bioacoustic-classifier/data/')

# %%
os.getcwd()
# Out:
# '/Users/jameshill/PycharmProjects/bioacoustic-classifier/data'

# %%
sample_rate,data = wavfile.read("processed/chunks_3s/20240611_050000_chunk_000.wav")

# %%
sample_rate
# Out:
# 48000

# %%
data
# Out:
# array([-2724, -3114, -2510, ..., -3178, -2967, -2226], dtype=int16)

# %%
plt.figure(figsize=(10, 4))
plt.specgram(data, Fs=sample_rate, NFFT=1024, noverlap=512, cmap='viridis')
plt.axis("off")
plt.subplots_adjust(left=0, right=1, top=1, bottom=0)
plt.show()
